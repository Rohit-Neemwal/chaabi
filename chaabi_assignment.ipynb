# %% [markdown]
# INSTALL DEPENDENCIES
# - qdrant_client
# - sentence_transformers
# - os
# - OPENAI

# %%
# !pip -q install qdrant-client
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 47.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 71.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.1 which is incompatible.

# %%
# !pip -q install sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.2 MB/s eta 0:00:00
#   Building wheel for sentence_transformers (setup.py) ... done

# %%
from qdrant_client import models,QdrantClient
from sentence_transformers import SentenceTransformer

# %% [markdown]
# USE MINI LANGUAGE MODEL TO ENCODE ENTRIES

# %%
encoder = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import csv

# csv_file_path = '/content/drive/MyDrive/chaabi/bigBasketProducts.csv'
# documents = list(csv.DictReader(open(csv_file_path)))

# %% [markdown]
# SET API FOR QDRANT DATABASE

# %%
qdrant= QdrantClient(
    url="https://a8ddd992-7d4b-450a-a29e-0d2a3502f278.us-east4-0.gcp.cloud.qdrant.io:6333",
    api_key="BbJFJznq0pXmuWGLlIlVfo8F0jmSb3gRRCi5-2uHQIwcUyrYqM54BQ",
)

# %%
# qdrant.delete_collection(collection_name="items_log")

# qdrant.recreate_collection(
#     collection_name = "items_log",
#     vectors_config =  models.VectorParams(
#             size = encoder.get_sentence_embedding_dimension(),
#             distance = models.Distance.COSINE
#         )
# )
# Out:
# True

# %% [markdown]
# MAKE THE EMBEDDING AND UPLOAD TO THE DATABASE

# %%
# from qdrant_client.http.models import PointStruct
# from tqdm import tqdm

# for index in tqdm(range(len(documents))):
#     doc = documents[index]
#     qdrant.upsert(
#         collection_name="items_log",
#         points=[
#             PointStruct(
#                 id=index,
#                 vector=encoder.encode(
#                     'description : ' + doc['description'] +
#                     ' index : ' +  doc['index'] +
#                     ' product : ' +  doc['product'] +
#                     ' sub_category : '+ doc['sub_category']+
#                     ' brand : ' + doc['brand'] +
#                     ' sales_price : '+ doc['sale_price']+
#                     ' market_price : ' + doc['market_price'] +
#                     ' typ : '+ doc['type'] +
#                     ' rating : ' + doc['rating']
#                  ).tolist(),
#                 payload= doc,
#             )
#         ]
#     )
# Out:
# 100%|██████████| 27555/27555 [1:04:16<00:00,  7.14it/s]

# %%
# !pip install openai
import openai
from openai import OpenAI
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.3.5)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.25.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.10.13)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai) (4.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai) (1.1.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Requirement already satisfied: httpcore in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore->httpx<1,>=0.23.0->openai) (0.14.0)

# %% [markdown]
# EXTRACT 10 RESULT CONTEXT FROM THE DATABASE

# %%
query = "best wheat"

hits = qdrant.search(
    collection_name = 'items_log',
    query_vector = encoder.encode(query).tolist(),
    limit = 10
)

# %% [markdown]
# INTEGRATE CHATGPT-3.5 TO THE CONTEXT AND OUTPUT THE RESULT

# %%
#


context = str(hits)
question = query

custom_prompt = """
use the context and provide the helpful answers. context is from online store product and you are asked
to answer the query by the user appropiately. and present all the attributes(price, name,company etc.) of context in good way.if
you don't know what to answer. then simply suggest another product.
Context: {0}


Query: {1}
Helpful Answer:
"""
custom_prompt = custom_prompt.format(context, question)

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
   api_key = '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',
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": custom_prompt,
        }
    ],
    model="gpt-3.5-turbo",
    temperature = 0.4,
)



model_response_content = chat_completion.choices[0].message.content
print(model_response_content)
# Out:
# The best wheat products available are:
#
# 1. Wheat - Whole by bb Royal:
#    - Brand: bb Royal
#    - Category: Foodgrains, Oil & Masala
#    - Description: Whole wheat light brown coloured spindle-shaped, tough, starchy and rich-tasting husked kernels of the wheat crop. Naturally low in gluten and has a low glycemic index. It is naturally rich in fiber, vitamins, minerals, and other nutrients.
#    - Market Price: 275
#    - Sale Price: 234
#    - Rating: 4.1
#
# 2. Wheat Broken/Dalia by bb Royal:
#    - Brand: bb Royal
#    - Category: Foodgrains, Oil & Masala
#    - Description: Broken wheat commonly used to make upma, porridge, and desserts. It is low in gluten and has a low glycemic index. It is naturally rich in fiber, vitamins, minerals, and other nutrients.
#    - Market Price: 80
#    - Sale Price: 52
#
# 3. Barley Flour by Nutty Yogi:
#    - Brand: Nutty Yogi
#    - Category: Gourmet & World Food
#    - Description: Barley flour is an excellent source of both soluble and insoluble fiber. It is known for its various health benefits and is recommended for people suffering from various health conditions.
#    - Market Price: 99
#    - Sale Price: 99
#    - Rating: 4.3
#
# 4. Wheat Bran - Germinated by Bagrrys:
#    - Brand: Bagrrys
#    - Category: Snacks & Branded Foods
#    - Description: Wheat Bran is the richest source of insoluble fiber and is considered a natural laxative. It is beneficial for weight watchers and helps reduce the risk of colon and rectum cancer.
#    - Market Price: 99
#    - Sale Price: 99
#    - Rating: 4.3
#
# 5. Fields of Gold Organic Wheat Flour by PRISTINE:
#    - Brand: PRISTINE
#    - Category: Foodgrains, Oil & Masala
#    - Description: Whole wheat grains known as 'Golden Grains', rich in vitamins, minerals, protein, and fiber. Pristine's Organic Wheat Flour is milled traditionally to retain its wholesome goodness. It is certified organic.
#    - Market Price: 285
#    - Sale Price: 276.45
#    - Rating: 4
#
# If you are looking for other wheat products, I can suggest more options.
